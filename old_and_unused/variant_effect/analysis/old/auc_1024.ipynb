# %%
import numpy as np
import pandas as pd
import sys
import os

import matplotlib
import matplotlib.pyplot as plt

import sklearn.metrics
from sklearn.metrics import roc_auc_score, roc_curve
from joblib import Parallel, delayed
from sklearn.utils import resample

import scipy.stats

sys.path.append("/home/icb/sergey.vilov/workspace/MLM/utils") 

import misc

from misc import model_colors

# %%
from IPython.display import display, HTML
display(HTML("<style>.jp-OutputArea-output {display:flex}</style>"))
# Out:
# <style>.jp-OutputArea-output {display:flex}</style>

# %%
data_dir = '/lustre/groups/epigenereg01/workspace/projects/vale/mlm/'

# %% [markdown]
# # Compute AUC
#
# for each split, compute AUC and get confidence intervals via bootstrapping

# %%
models = ['DNABERT', 'DNABERT-3UTR', 'DNABERT-2','DNABERT2-ZOO', 'DNABERT2-3UTR', 'NT-MS-v2-100M','NTv2-100M-3UTR',
         'StateSpace', 'StateSpace-SA', 'StateSpace-DNA','StateSpace-SA-DNA', 'PhyloP-100way', 'PhyloP-241way','CADD','Zoo-AL']

# %%
utr_variants = pd.read_csv(data_dir + 'variants_1024/variant_scores.tsv.gz', sep='\t')

utr_variants.groupby('split').label.value_counts()
# Out:
# split       label
# CADD        0.0      10000
#             1.0      10000
# clinvar     0.0      10000
#             1.0        261
# eQTL-susie  0.0      10000
#             1.0      10000
# gnomAD      0.0      10000
#             1.0      10000
# Name: count, dtype: int64

# %%
scores = ['pref','palt_inv','pratio','l1','l2','dot','cosine', 
          'loss_alt','loss_diff','raw','phred','MLP','score','VIS']

# %%
def calculate_auc(y_true, y_pred, seed):
    y_pred_resampled, y_true_resampled = resample(y_pred, y_true, random_state=seed)
    auc = roc_auc_score(y_true_resampled, y_pred_resampled)
    return auc
    
def bootstrap_auc(y_true, y_pred, n_iterations=1000, ci_percentile=95):

    all_scores = Parallel(n_jobs=-1)(delayed(calculate_auc)(y_true, y_pred,i) for i in range(n_iterations))

    # Compute the confidence interval
    ci_lower = np.percentile(all_scores, (100 - ci_percentile) / 2)
    ci_upper = np.percentile(all_scores, 100 - (100 - ci_percentile) / 2)
    
    score_mean = np.mean(all_scores)
    score_err = (ci_upper-ci_lower)/2
    
    return score_mean, score_err

def bootstrap_score(df):

    print(f'Computing AUC for {df.name}')
    
    roc_df = []
    
    for model_name in models:
    
        print(model_name)
    
        model_scores = []
            
        for score_name in scores:
            if score_name == 'pref':
                if f'{model_name}-pref' not in df.columns:
                    model_scores.append((0,0))
                    continue
                score = df[f'{model_name}-pref']
            elif score_name == 'palt_inv':
                if f'{model_name}-palt' not in df.columns:
                    model_scores.append((0,0))
                    continue
                score = -np.log(df[f'{model_name}-palt']+1e-14)
            elif score_name == 'pratio':
                if f'{model_name}-palt' not in df.columns:
                    model_scores.append((0,0))
                    continue
                score = np.log(df[f'{model_name}-pref']+1e-14)-np.log(df[f'{model_name}-palt']+1e-14)
            elif score_name == 'loss_diff':
                if f'{model_name}-loss_alt' not in df.columns:
                    model_scores.append((0,0))
                    continue
                score = df[f'{model_name}-loss_alt']-df[f'{model_name}-loss_ref']
            else:
                if f'{model_name}-{score_name}' not in df.columns:
                    model_scores.append((0,0))
                    continue
                score = df[f'{model_name}-{score_name}']

            y_true = df.label[~score.isna()].values
            y_pred = score[~score.isna()].values
            bootstrap_est = bootstrap_auc(y_true, y_pred)
            model_scores.append(bootstrap_est)
            
        roc_df.append((model_name, *model_scores))
        
    roc_df = pd.DataFrame(roc_df,columns=['model'] + scores)
    return roc_df

# %%
roc_df = utr_variants.groupby('split').apply(bootstrap_score,include_groups=False)
# Out:
# Computing AUC for CADD
# DNABERT
# DNABERT-3UTR
# DNABERT-2
# DNABERT2-ZOO
# DNABERT2-3UTR
# NT-MS-v2-100M
# NTv2-100M-3UTR
# StateSpace
# StateSpace-SA
# StateSpace-DNA
# StateSpace-SA-DNA
# PhyloP-100way
# PhyloP-241way
# CADD
# Zoo-AL
# Computing AUC for clinvar
# DNABERT
# DNABERT-3UTR
# DNABERT-2
# DNABERT2-ZOO
# DNABERT2-3UTR
# NT-MS-v2-100M
# NTv2-100M-3UTR
# StateSpace
# StateSpace-SA
# StateSpace-DNA
# StateSpace-SA-DNA
# PhyloP-100way
# PhyloP-241way
# CADD
# Zoo-AL
# Computing AUC for eQTL-susie
# DNABERT
# DNABERT-3UTR
# DNABERT-2
# DNABERT2-ZOO
# DNABERT2-3UTR
# NT-MS-v2-100M
# NTv2-100M-3UTR
# StateSpace
# StateSpace-SA
# StateSpace-DNA
# StateSpace-SA-DNA
# PhyloP-100way
# PhyloP-241way
# CADD
# Zoo-AL
# Computing AUC for gnomAD
# DNABERT
# DNABERT-3UTR
# DNABERT-2
# DNABERT2-ZOO
# DNABERT2-3UTR
# NT-MS-v2-100M
# NTv2-100M-3UTR
# StateSpace
# StateSpace-SA
# StateSpace-DNA
# StateSpace-SA-DNA
# PhyloP-100way
# PhyloP-241way
# CADD
# Zoo-AL

# %%
roc_df = roc_df.droplevel(-1).reset_index()

# %%
roc_df.to_parquet(data_dir + f'variants/auc.parquet')

# %% [markdown]
# # Make auc table

# %%
alignment_based_models = ['PhyloP-100way', 'PhyloP-241way','CADD','Zoo-AL']
language_models = ['DNABERT', 'DNABERT-3UTR', 
                   'DNABERT-2','DNABERT2-ZOO', 'DNABERT2-3UTR', 
                   'NT-MS-v2-100M','NTv2-100M-3UTR',
                    'StateSpace', 'StateSpace-DNA',]

subsets = ['clinvar','gnomAD','eQTL-susie','CADD',]

# %%
roc_df = pd.read_parquet(data_dir + f'variants/auc.parquet')

roc_df = roc_df[roc_df.model.isin(alignment_based_models+language_models)].set_index(['split','model']).loc[subsets]

# %%
roc_df = roc_df.map(lambda x:(1-x[0],x[1]) if x[0]<0.5 and x[0]>0 else tuple(x))

roc_df = roc_df.map(lambda x: (round(x[0],3),round(x[1],3)))

# %%
zero_shot_LM = roc_df.loc[roc_df.index.get_level_values('model').isin(language_models),['pref', 'palt_inv', 'pratio', 'VIS', 'l1', 'l2', 'dot', 'cosine', 'loss_alt',
       'loss_diff']]

zero_shot_AB = roc_df.loc[roc_df.index.get_level_values('model').isin(alignment_based_models),['raw','score','pref', 'palt_inv', 'pratio']]

# %%
def is_overlap(a, b):
    return max(0, min(a[1], b[1]) - max(a[0], b[0]))>0

def get_best_models(zero_shot_df):

    best_models = {}
        
    for split in subsets:
            
        split_data = zero_shot_df.loc[split]
            
        best_auc, best_auc_err =  sorted(split_data.values.flatten())[-1]
        
        best_models[split] = []
        
        for model in split_data.columns:
            for score in split_data.index:
                auc, auc_err = split_data.loc[score,model]
                    #print (split,model,score,auc,auc_err,'T')
                if auc-auc_err>0.5 and is_overlap((best_auc-best_auc_err,best_auc+best_auc_err),(auc-auc_err,auc+auc_err)):
                    #print (split,model,score,auc,auc_err)
                    best_models[split].append((model,score))

    return best_models

def get_color(x):
    
    auc = x[0]
    auc = max(auc-0.5,0)
    auc = min(auc,0.8)/0.8
    cmap = matplotlib.colormaps['Oranges']
    rgb_code=(np.array(cmap(auc))*255).astype(int)
    hex_code='#{:02x}{:02x}{:02x}'.format(*rgb_code[:3])
    
    return hex_code

# %%
zero_shot_LM = zero_shot_LM.reset_index().groupby('split', sort=False).apply(lambda x:x.set_index('model').T,include_groups=False)

# %%
def reshape_AB_df(df):
    new_s = pd.Series()
    new_s['PhyloP-100way-score'] = df.loc['PhyloP-100way','score']
    new_s['PhyloP-241way-score'] = df.loc['PhyloP-241way','score']
    new_s['CADD-raw'] = df.loc['CADD','raw']
    new_s['Zoo-AL-pref'] = df.loc['Zoo-AL','pref']
    new_s['Zoo-AL-palt_inv'] = df.loc['Zoo-AL','palt_inv']
    new_s['Zoo-AL-pratio'] = df.loc['Zoo-AL','pratio']
    return new_s
    
zero_shot_AB = zero_shot_AB.reset_index('split').groupby('split', sort=False).apply(reshape_AB_df,include_groups=False)

# %%
best_models_AB = zero_shot_AB.T.apply(misc.get_best_models).to_dict()

def highlight_ns_AB(x):
    column_name = x.name
    return [f'font-weight: bold;background-color: {get_color(zero_shot_AB.loc[column_name,model])}' 
            if model in list(best_models_AB[column_name]) 
            else f'background-color: {get_color(zero_shot_AB.loc[column_name,model])}'
            for model in x.index]

zero_shot_AB_ = zero_shot_AB.map(lambda x: f'{x[0]:.3f}±{x[1]:.3f}' if x!=(0,0) else '-')

#styler=zero_shot_AB_.style.apply(highlight_ns_AB,axis=1)
styler=zero_shot_AB_.T.style.apply(lambda x:misc.highlight_ns(x,best_models_AB),axis=0)
styler
# Out:
# <style type="text/css">
# #T_7d8f0_row0_col2, #T_7d8f0_row2_col0, #T_7d8f0_row2_col2, #T_7d8f0_row3_col1, #T_7d8f0_row3_col2, #T_7d8f0_row4_col1, #T_7d8f0_row4_col2, #T_7d8f0_row5_col1, #T_7d8f0_row5_col2, #T_7d8f0_row5_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_7d8f0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >split</th>
#       <th id="T_7d8f0_level0_col0" class="col_heading level0 col0" >clinvar</th>
#       <th id="T_7d8f0_level0_col1" class="col_heading level0 col1" >gnomAD</th>
#       <th id="T_7d8f0_level0_col2" class="col_heading level0 col2" >eQTL-susie</th>
#       <th id="T_7d8f0_level0_col3" class="col_heading level0 col3" >CADD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d8f0_level0_row0" class="row_heading level0 row0" >PhyloP-100way-score</th>
#       <td id="T_7d8f0_row0_col0" class="data row0 col0" >0.915±0.021</td>
#       <td id="T_7d8f0_row0_col1" class="data row0 col1" >0.620±0.007</td>
#       <td id="T_7d8f0_row0_col2" class="data row0 col2" >0.519±0.008</td>
#       <td id="T_7d8f0_row0_col3" class="data row0 col3" >0.693±0.008</td>
#     </tr>
#     <tr>
#       <th id="T_7d8f0_level0_row1" class="row_heading level0 row1" >PhyloP-241way-score</th>
#       <td id="T_7d8f0_row1_col0" class="data row1 col0" >0.908±0.025</td>
#       <td id="T_7d8f0_row1_col1" class="data row1 col1" >0.623±0.008</td>
#       <td id="T_7d8f0_row1_col2" class="data row1 col2" >0.500±0.008</td>
#       <td id="T_7d8f0_row1_col3" class="data row1 col3" >0.655±0.007</td>
#     </tr>
#     <tr>
#       <th id="T_7d8f0_level0_row2" class="row_heading level0 row2" >CADD-raw</th>
#       <td id="T_7d8f0_row2_col0" class="data row2 col0" >0.976±0.015</td>
#       <td id="T_7d8f0_row2_col1" class="data row2 col1" >0.610±0.007</td>
#       <td id="T_7d8f0_row2_col2" class="data row2 col2" >0.517±0.008</td>
#       <td id="T_7d8f0_row2_col3" class="data row2 col3" >0.690±0.007</td>
#     </tr>
#     <tr>
#       <th id="T_7d8f0_level0_row3" class="row_heading level0 row3" >Zoo-AL-pref</th>
#       <td id="T_7d8f0_row3_col0" class="data row3 col0" >0.868±0.019</td>
#       <td id="T_7d8f0_row3_col1" class="data row3 col1" >0.689±0.007</td>
#       <td id="T_7d8f0_row3_col2" class="data row3 col2" >0.520±0.008</td>
#       <td id="T_7d8f0_row3_col3" class="data row3 col3" >0.931±0.003</td>
#     </tr>
#     <tr>
#       <th id="T_7d8f0_level0_row4" class="row_heading level0 row4" >Zoo-AL-palt_inv</th>
#       <td id="T_7d8f0_row4_col0" class="data row4 col0" >0.881±0.013</td>
#       <td id="T_7d8f0_row4_col1" class="data row4 col1" >0.695±0.007</td>
#       <td id="T_7d8f0_row4_col2" class="data row4 col2" >0.525±0.008</td>
#       <td id="T_7d8f0_row4_col3" class="data row4 col3" >0.940±0.003</td>
#     </tr>
#     <tr>
#       <th id="T_7d8f0_level0_row5" class="row_heading level0 row5" >Zoo-AL-pratio</th>
#       <td id="T_7d8f0_row5_col0" class="data row5 col0" >0.890±0.013</td>
#       <td id="T_7d8f0_row5_col1" class="data row5 col1" >0.701±0.007</td>
#       <td id="T_7d8f0_row5_col2" class="data row5 col2" >0.523±0.008</td>
#       <td id="T_7d8f0_row5_col3" class="data row5 col3" >0.951±0.003</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_models_LM = get_best_models(zero_shot_LM)

def highlight_ns_LM(x):
    split, score = x.name
    return [f'font-weight: bold;background-color: {get_color(zero_shot_LM.loc[(split,score),model])}' 
            if (model,score) in best_models_LM[split] else f'background-color: {get_color(zero_shot_LM.loc[(split,score),model])}'
                for model in x.index]

zero_shot_LM_ = zero_shot_LM.map(lambda x: f'{x[0]:.3f}±{x[1]:.3f}' if x!=(0,0) else '-')

styler=zero_shot_LM_.style.apply(highlight_ns_LM,axis=1)
styler
# Out:
# <style type="text/css">
# #T_a7318_row0_col0, #T_a7318_row0_col6, #T_a7318_row7_col6, #T_a7318_row9_col6, #T_a7318_row16_col5, #T_a7318_row17_col4, #T_a7318_row18_col0, #T_a7318_row24_col2, #T_a7318_row24_col3, #T_a7318_row25_col3, #T_a7318_row34_col0, #T_a7318_row34_col4, #T_a7318_row35_col0, #T_a7318_row35_col4, #T_a7318_row36_col0, #T_a7318_row37_col8, #T_a7318_row38_col0, #T_a7318_row39_col1 {
#   background-color: #fef3e7;
# }
# #T_a7318_row0_col1, #T_a7318_row0_col2, #T_a7318_row0_col3, #T_a7318_row0_col4, #T_a7318_row1_col2, #T_a7318_row1_col3, #T_a7318_row1_col4, #T_a7318_row2_col2, #T_a7318_row2_col3, #T_a7318_row2_col4, #T_a7318_row2_col8, #T_a7318_row3_col0, #T_a7318_row3_col1, #T_a7318_row3_col2, #T_a7318_row3_col3, #T_a7318_row3_col4, #T_a7318_row3_col5, #T_a7318_row3_col6, #T_a7318_row3_col7, #T_a7318_row3_col8, #T_a7318_row9_col7, #T_a7318_row10_col2, #T_a7318_row10_col3, #T_a7318_row10_col4, #T_a7318_row11_col2, #T_a7318_row11_col3, #T_a7318_row11_col4, #T_a7318_row12_col2, #T_a7318_row12_col3, #T_a7318_row12_col4, #T_a7318_row13_col0, #T_a7318_row13_col1, #T_a7318_row13_col2, #T_a7318_row13_col3, #T_a7318_row13_col4, #T_a7318_row13_col5, #T_a7318_row13_col6, #T_a7318_row13_col7, #T_a7318_row13_col8, #T_a7318_row14_col6, #T_a7318_row15_col6, #T_a7318_row16_col0, #T_a7318_row17_col6, #T_a7318_row18_col4, #T_a7318_row19_col0, #T_a7318_row19_col2, #T_a7318_row20_col2, #T_a7318_row20_col3, #T_a7318_row20_col4, #T_a7318_row21_col1, #T_a7318_row21_col2, #T_a7318_row21_col3, #T_a7318_row21_col4, #T_a7318_row21_col5, #T_a7318_row21_col8, #T_a7318_row22_col2, #T_a7318_row22_col3, #T_a7318_row22_col4, #T_a7318_row23_col0, #T_a7318_row23_col1, #T_a7318_row23_col2, #T_a7318_row23_col3, #T_a7318_row23_col4, #T_a7318_row23_col5, #T_a7318_row23_col6, #T_a7318_row23_col7, #T_a7318_row23_col8, #T_a7318_row24_col7, #T_a7318_row24_col8, #T_a7318_row25_col7, #T_a7318_row25_col8, #T_a7318_row27_col2, #T_a7318_row27_col6, #T_a7318_row28_col0, #T_a7318_row28_col1, #T_a7318_row29_col0, #T_a7318_row29_col2, #T_a7318_row29_col3, #T_a7318_row29_col4, #T_a7318_row29_col6, #T_a7318_row29_col7, #T_a7318_row30_col2, #T_a7318_row30_col3, #T_a7318_row30_col4, #T_a7318_row31_col2, #T_a7318_row31_col3, #T_a7318_row31_col4, #T_a7318_row32_col2, #T_a7318_row32_col3, #T_a7318_row32_col4, #T_a7318_row33_col0, #T_a7318_row33_col1, #T_a7318_row33_col2, #T_a7318_row33_col3, #T_a7318_row33_col4, #T_a7318_row33_col5, #T_a7318_row33_col6, #T_a7318_row33_col7, #T_a7318_row33_col8, #T_a7318_row34_col2, #T_a7318_row34_col3, #T_a7318_row35_col2, #T_a7318_row35_col3, #T_a7318_row39_col0, #T_a7318_row39_col5, #T_a7318_row39_col6 {
#   background-color: #fff5eb;
# }
# #T_a7318_row0_col5, #T_a7318_row1_col1, #T_a7318_row7_col0 {
#   background-color: #feeddb;
# }
# #T_a7318_row0_col7, #T_a7318_row7_col3, #T_a7318_row7_col7, #T_a7318_row9_col3, #T_a7318_row18_col7, #T_a7318_row24_col0, #T_a7318_row25_col0, #T_a7318_row25_col2 {
#   background-color: #fef2e6;
# }
# #T_a7318_row0_col8, #T_a7318_row2_col1, #T_a7318_row4_col3, #T_a7318_row8_col3, #T_a7318_row9_col2, #T_a7318_row9_col4, #T_a7318_row18_col8, #T_a7318_row38_col5 {
#   background-color: #fef2e5;
# }
# #T_a7318_row1_col0, #T_a7318_row1_col5, #T_a7318_row5_col8, #T_a7318_row7_col4, #T_a7318_row9_col0, #T_a7318_row10_col6, #T_a7318_row16_col2, #T_a7318_row16_col6, #T_a7318_row17_col1, #T_a7318_row17_col2, #T_a7318_row36_col6 {
#   background-color: #feefe0;
# }
# #T_a7318_row1_col6, #T_a7318_row8_col0, #T_a7318_row36_col2 {
#   background-color: #fef0e1;
# }
# #T_a7318_row1_col7, #T_a7318_row36_col4 {
#   background-color: #feeede;
# }
# #T_a7318_row1_col8, #T_a7318_row4_col8, #T_a7318_row6_col2, #T_a7318_row12_col5 {
#   background-color: #feeedf;
# }
# #T_a7318_row2_col0, #T_a7318_row4_col7, #T_a7318_row5_col7, #T_a7318_row9_col8, #T_a7318_row14_col5, #T_a7318_row15_col5, #T_a7318_row18_col1, #T_a7318_row18_col3, #T_a7318_row18_col5, #T_a7318_row18_col6, #T_a7318_row19_col4, #T_a7318_row19_col5, #T_a7318_row20_col0, #T_a7318_row20_col1, #T_a7318_row20_col6, #T_a7318_row20_col7, #T_a7318_row20_col8, #T_a7318_row21_col0, #T_a7318_row22_col0, #T_a7318_row22_col6, #T_a7318_row24_col4, #T_a7318_row24_col5, #T_a7318_row24_col6, #T_a7318_row25_col4, #T_a7318_row25_col5, #T_a7318_row25_col6, #T_a7318_row27_col0, #T_a7318_row27_col7, #T_a7318_row28_col3, #T_a7318_row28_col4, #T_a7318_row29_col1, #T_a7318_row34_col8, #T_a7318_row35_col8, #T_a7318_row37_col4, #T_a7318_row37_col5, #T_a7318_row38_col1, #T_a7318_row38_col3 {
#   background-color: #fef4e9;
# }
# #T_a7318_row2_col5, #T_a7318_row2_col7, #T_a7318_row17_col5, #T_a7318_row19_col3, #T_a7318_row20_col5, #T_a7318_row21_col6, #T_a7318_row21_col7, #T_a7318_row22_col1, #T_a7318_row22_col5, #T_a7318_row22_col7, #T_a7318_row22_col8, #T_a7318_row26_col1, #T_a7318_row27_col1, #T_a7318_row27_col3, #T_a7318_row27_col4, #T_a7318_row27_col5, #T_a7318_row27_col8, #T_a7318_row28_col6, #T_a7318_row29_col5, #T_a7318_row29_col8, #T_a7318_row34_col7, #T_a7318_row35_col7, #T_a7318_row37_col1, #T_a7318_row37_col3, #T_a7318_row38_col6, #T_a7318_row39_col4 {
#   background-color: #fef4ea;
# }
# #T_a7318_row2_col6, #T_a7318_row4_col4, #T_a7318_row5_col3, #T_a7318_row5_col4, #T_a7318_row14_col0, #T_a7318_row14_col1, #T_a7318_row14_col2, #T_a7318_row14_col3, #T_a7318_row15_col0, #T_a7318_row15_col2, #T_a7318_row15_col3, #T_a7318_row16_col3, #T_a7318_row17_col0, #T_a7318_row18_col2, #T_a7318_row26_col0, #T_a7318_row26_col6, #T_a7318_row36_col7, #T_a7318_row36_col8, #T_a7318_row38_col2, #T_a7318_row38_col7, #T_a7318_row38_col8 {
#   background-color: #fef1e3;
# }
# #T_a7318_row4_col0, #T_a7318_row7_col5, #T_a7318_row30_col1, #T_a7318_row30_col7 {
#   background-color: #fde5cc;
# }
# #T_a7318_row4_col1, #T_a7318_row31_col7 {
#   background-color: #fde4cb;
# }
# #T_a7318_row4_col2, #T_a7318_row8_col7 {
#   background-color: #fde0c2;
# }
# #T_a7318_row4_col5, #T_a7318_row5_col5, #T_a7318_row31_col0, #T_a7318_row32_col0 {
#   background-color: #fde2c6;
# }
# #T_a7318_row4_col6, #T_a7318_row5_col6, #T_a7318_row11_col5, #T_a7318_row16_col4, #T_a7318_row19_col1, #T_a7318_row19_col6 {
#   background-color: #feeddd;
# }
# #T_a7318_row5_col0, #T_a7318_row8_col2, #T_a7318_row31_col5 {
#   background-color: #fde5cd;
# }
# #T_a7318_row5_col1, #T_a7318_row6_col7, #T_a7318_row30_col8, #T_a7318_row31_col8, #T_a7318_row32_col8 {
#   background-color: #fee6ce;
# }
# #T_a7318_row5_col2 {
#   background-color: #fdddbd;
# }
# #T_a7318_row6_col0 {
#   font-weight: bold;
#   background-color: #fdd2a7;
# }
# #T_a7318_row6_col1, #T_a7318_row10_col5, #T_a7318_row16_col7, #T_a7318_row16_col8, #T_a7318_row28_col2, #T_a7318_row36_col3, #T_a7318_row36_col5, #T_a7318_row37_col6, #T_a7318_row39_col2 {
#   background-color: #fef1e4;
# }
# #T_a7318_row6_col3, #T_a7318_row6_col5 {
#   background-color: #fddcbb;
# }
# #T_a7318_row6_col4, #T_a7318_row39_col8 {
#   background-color: #fee8d3;
# }
# #T_a7318_row6_col6 {
#   background-color: #fdd3a9;
# }
# #T_a7318_row6_col8, #T_a7318_row17_col7 {
#   background-color: #feebd8;
# }
# #T_a7318_row7_col1, #T_a7318_row30_col5, #T_a7318_row39_col7 {
#   background-color: #fee8d2;
# }
# #T_a7318_row7_col2, #T_a7318_row30_col6 {
#   background-color: #fddebe;
# }
# #T_a7318_row7_col8, #T_a7318_row14_col4, #T_a7318_row15_col4, #T_a7318_row24_col1, #T_a7318_row25_col1, #T_a7318_row34_col1, #T_a7318_row34_col5, #T_a7318_row35_col1, #T_a7318_row35_col5, #T_a7318_row37_col0, #T_a7318_row37_col2, #T_a7318_row37_col7, #T_a7318_row38_col4, #T_a7318_row39_col3 {
#   background-color: #fef3e8;
# }
# #T_a7318_row8_col1 {
#   background-color: #fee9d5;
# }
# #T_a7318_row8_col4 {
#   font-weight: bold;
#   background-color: #fdd4ab;
# }
# #T_a7318_row8_col5 {
#   background-color: #fddfc1;
# }
# #T_a7318_row8_col6 {
#   font-weight: bold;
#   background-color: #fdc28c;
# }
# #T_a7318_row8_col8 {
#   background-color: #fde1c4;
# }
# #T_a7318_row9_col1, #T_a7318_row9_col5, #T_a7318_row15_col1, #T_a7318_row16_col1, #T_a7318_row17_col3, #T_a7318_row34_col6, #T_a7318_row35_col6, #T_a7318_row36_col1 {
#   background-color: #fef0e2;
# }
# #T_a7318_row10_col0, #T_a7318_row10_col8, #T_a7318_row11_col6, #T_a7318_row11_col7, #T_a7318_row11_c

# %%
#styler.to_excel(data_dir + 'all_scores/auc_zero_shot.xlsx')
#roc_df.to_csv(data_dir + 'all_scores/auc_all.tsv',sep='\t')

data_dir + 'all_scores/auc_zero_shot.xlsx'
# Out:
# '/lustre/groups/epigenereg01/workspace/projects/vale/mlm/all_scores/auc_zero_shot.xlsx'

# %%
#models_df = roc_df[['score','MLP','raw','pratio']].apply(lambda x:x.sort_values().iloc[-1],axis=1).rename('auc').reset_index()
models_df = roc_df[['MLP']].apply(lambda x:x.sort_values().iloc[-1],axis=1).rename('auc').reset_index()

models_df = models_df.pivot(columns='split',index='model',values='auc').loc[language_models,subsets]

best_models = models_df.apply(misc.get_best_models).to_dict()

models_df_ = models_df.map(lambda x: f'{x[0]:.3f}±{x[1]:.3f}')

models_df_.iloc[:,:4].style.apply(lambda x: misc.highlight_ns(x, best_models))
# Out:
# <style type="text/css">
# #T_941ef_row0_col0, #T_941ef_row0_col1, #T_941ef_row0_col3, #T_941ef_row1_col0, #T_941ef_row1_col1, #T_941ef_row1_col3, #T_941ef_row2_col0, #T_941ef_row3_col0, #T_941ef_row3_col1, #T_941ef_row3_col2, #T_941ef_row4_col0, #T_941ef_row4_col1, #T_941ef_row7_col0, #T_941ef_row7_col1, #T_941ef_row7_col3, #T_941ef_row8_col0, #T_941ef_row8_col1, #T_941ef_row8_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_941ef">
#   <thead>
#     <tr>
#       <th class="index_name level0" >split</th>
#       <th id="T_941ef_level0_col0" class="col_heading level0 col0" >clinvar</th>
#       <th id="T_941ef_level0_col1" class="col_heading level0 col1" >gnomAD</th>
#       <th id="T_941ef_level0_col2" class="col_heading level0 col2" >eQTL-susie</th>
#       <th id="T_941ef_level0_col3" class="col_heading level0 col3" >CADD</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_941ef_level0_row0" class="row_heading level0 row0" >DNABERT</th>
#       <td id="T_941ef_row0_col0" class="data row0 col0" >0.934±0.019</td>
#       <td id="T_941ef_row0_col1" class="data row0 col1" >0.582±0.008</td>
#       <td id="T_941ef_row0_col2" class="data row0 col2" >0.572±0.008</td>
#       <td id="T_941ef_row0_col3" class="data row0 col3" >0.599±0.008</td>
#     </tr>
#     <tr>
#       <th id="T_941ef_level0_row1" class="row_heading level0 row1" >DNABERT-3UTR</th>
#       <td id="T_941ef_row1_col0" class="data row1 col0" >0.946±0.017</td>
#       <td id="T_941ef_row1_col1" class="data row1 col1" >0.589±0.008</td>
#       <td id="T_941ef_row1_col2" class="data row1 col2" >0.600±0.007</td>
#       <td id="T_941ef_row1_col3" class="data row1 col3" >0.602±0.008</td>
#     </tr>
#     <tr>
#       <th id="T_941ef_level0_row2" class="row_heading level0 row2" >DNABERT-2</th>
#       <td id="T_941ef_row2_col0" class="data row2 col0" >0.958±0.016</td>
#       <td id="T_941ef_row2_col1" class="data row2 col1" >0.567±0.008</td>
#       <td id="T_941ef_row2_col2" class="data row2 col2" >0.787±0.006</td>
#       <td id="T_941ef_row2_col3" class="data row2 col3" >0.539±0.008</td>
#     </tr>
#     <tr>
#       <th id="T_941ef_level0_row3" class="row_heading level0 row3" >DNABERT2-ZOO</th>
#       <td id="T_941ef_row3_col0" class="data row3 col0" >0.956±0.018</td>
#       <td id="T_941ef_row3_col1" class="data row3 col1" >0.588±0.008</td>
#       <td id="T_941ef_row3_col2" class="data row3 col2" >0.831±0.006</td>
#       <td id="T_941ef_row3_col3" class="data row3 col3" >0.537±0.008</td>
#     </tr>
#     <tr>
#       <th id="T_941ef_level0_row4" class="row_heading level0 row4" >DNABERT2-3UTR</th>
#       <td id="T_941ef_row4_col0" class="data row4 col0" >0.950±0.019</td>
#       <td id="T_941ef_row4_col1" class="data row4 col1" >0.590±0.008</td>
#       <td id="T_941ef_row4_col2" class="data row4 col2" >0.717±0.007</td>
#       <td id="T_941ef_row4_col3" class="data row4 col3" >0.543±0.008</td>
#     </tr>
#     <tr>
#       <th id="T_941ef_level0_row5" class="row_heading level0 row5" >NT-MS-v2-100M</th>
#       <td id="T_941ef_row5_col0" class="data row5 col0" >0.906±0.025</td>
#       <td id="T_941ef_row5_col1" class="data row5 col1" >0.551±0.008</td>
#       <td id="T_941ef_row5_col2" class="data row5 col2" >0.598±0.008</td>
#       <td id="T_941ef_row5_col3" class="data row5 col3" >0.533±0.008</td>
#     </tr>
#     <tr>
#       <th id="T_941ef_level0_row6" class="row_heading level0 row6" >NTv2-100M-3UTR</th>
#       <td id="T_941ef_row6_col0" class="data row6 col0" >0.919±0.021</td>
#       <td id="T_941ef_row6_col1" class="data row6 col1" >0.554±0.008</td>
#       <td id="T_941ef_row6_col2" class="data row6 col2" >0.588±0.008</td>
#       <td id="T_941ef_row6_col3" class="data row6 col3" >0.543±0.008</td>
#     </tr>
#     <tr>
#       <th id="T_941ef_level0_row7" class="row_heading level0 row7" >StateSpace</th>
#       <td id="T_941ef_row7_col0" class="data row7 col0" >0.930±0.023</td>
#       <td id="T_941ef_row7_col1" class="data row7 col1" >0.584±0.008</td>
#       <td id="T_941ef_row7_col2" class="data row7 col2" >0.645±0.007</td>
#       <td id="T_941ef_row7_col3" class="data row7 col3" >0.594±0.008</td>
#     </tr>
#     <tr>
#       <th id="T_941ef_level0_row8" class="row_heading level0 row8" >StateSpace-DNA</th>
#       <td id="T_941ef_row8_col0" class="data row8 col0" >0.925±0.022</td>
#       <td id="T_941ef_row8_col1" class="data row8 col1" >0.579±0.008</td>
#       <td id="T_941ef_row8_col2" class="data row8 col2" >0.644±0.007</td>
#       <td id="T_941ef_row8_col3" class="data row8 col3" >0.599±0.008</td>
#     </tr>
#   </tbody>
# </table>

# %%
def get_best_score(x):
    x = x.sort_values()
    return pd.Series({'score_name':x.index[-1],'auc':x.iloc[-1][0]})

best_score_df = roc_df[['pref','MLP','raw','score','phred']].apply(get_best_score,axis=1)

best_score_list = best_score_df.reset_index().sort_values(
    by=['split','auc'],ascending=False).set_index(['split','model']).auc

# %%
utr_variants = pd.read_csv(data_dir + 'all_scores/variant_scores.tsv.gz', sep='\t')

# %%
from matplotlib.ticker import FormatStrFormatter

matplotlib.rcParams.update({'font.size': 22})

fig, axes = plt.subplots(2,2, figsize=(14,10),dpi=300)

x = np.arange(0,1,0.01)

ax_idx = 0
for ax,split in zip(axes.flatten(),('clinvar','gnomAD','eQTL-susie','CADD')):
    ax_idx+=1
    text=[]
    for model_idx, (model,score_name) in enumerate(best_score_df.loc[split].score_name.items()):
        df = utr_variants[(utr_variants.split==split)][['label',model+'-'+score_name]].rename(columns={'label':'y_true',model+'-'+score_name:'y_pred'})
        df = df[~df.y_pred.isna()]
        fpr, tpr, _ = roc_curve(df.y_true,df.y_pred)
        if sklearn.metrics.auc(fpr,tpr)<0.5:
            fpr, tpr = tpr, fpr
        ax.plot(fpr,tpr,color=model_colors[model],label=model.replace("CADD","CADD-1.7"))
        ax.plot(x,x, linestyle=(0,(1,5)), color='k')
        ax.set_xticks([0,0.25,0.5,0.75,1])
        ax.xaxis.set_major_formatter(FormatStrFormatter('%.1f'))
        ax.set_yticks([0,0.25,0.5,0.75,1])
        ax.yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
    for model,auc in best_score_list.loc[split].iloc[:3].items():
        text.append(f'{model.replace("CADD","CADD-1.7")}={auc:.3f}')
    ax.text(1,0,'\n'.join(text),horizontalalignment='right',fontsize=16)
    if ax_idx==1 or ax_idx==3:
        ax.set_ylabel('True positive rate')
    if ax_idx==3 or ax_idx==4:
        ax.set_xlabel('False positive rate')
    if ax_idx==2:
        ax.legend(bbox_to_anchor=(1.7, 0.5),ncol=1, fontsize=16)

plt.subplots_adjust(wspace=0.3,hspace=0.3)

# %%
from matplotlib.ticker import FormatStrFormatter

matplotlib.rcParams.update({'font.size': 22})

fig, axes = plt.subplots(1,4, figsize=(25,5),dpi=300)

x = np.arange(0,1,0.01)

ax_idx = 0
for ax,split in zip(axes.flatten(),('clinvar','gnomAD','eQTL-susie','CADD')):
    ax_idx+=1
    text=[]
    for model_idx, (model,score_name) in enumerate(best_score_df.loc[split].score_name.items()):
        df = utr_variants[(utr_variants.split==split)][['label',model+'-'+score_name]].rename(columns={'label':'y_true',model+'-'+score_name:'y_pred'})
        df = df[~df.y_pred.isna()]
        fpr, tpr, _ = roc_curve(df.y_true,df.y_pred)
        if sklearn.metrics.auc(fpr,tpr)<0.5:
            fpr, tpr = tpr, fpr
        ax.plot(fpr,tpr,color=model_colors[model],label=model.replace("CADD","CADD-1.7"))
        ax.plot(x,x, linestyle=(0,(1,5)), color='k')
        ax.set_xticks([0,0.25,0.5,0.75,1])
        ax.xaxis.set_major_formatter(FormatStrFormatter('%.1f'))
        ax.set_yticks([0,0.25,0.5,0.75,1])
        ax.yaxis.set_major_formatter(FormatStrFormatter('%.1f'))
    for model,auc in best_score_list.loc[split].iloc[:3].items():
        text.append(f'{model.replace("CADD","CADD-1.7")}={auc:.3f}')
    ax.text(1,0,'\n'.join(text),horizontalalignment='right',fontsize=16)
    if ax_idx==1:
        ax.set_ylabel('True positive rate')
    ax.set_xlabel('False positive rate')
    if ax_idx==4:
        ax.legend(bbox_to_anchor=(1., 1.03),ncol=1, fontsize=16)

plt.subplots_adjust(wspace=0.3,hspace=0.3)
